# %% [markdown]
# <a href="https://colab.research.google.com/github/tngks28/iot_hw/blob/main/o3%25dust.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install beautifulsoup4
import requests
from bs4 import BeautifulSoup

# %%
import requests

# %%
r=requests.get('http://apis.data.go.kr/B552584/OzYlwsndOccrrncInforInqireSvc/getOzAdvsryOccrrncInfo?year=2020&pageNo=1&numOfRows=100&returnType=xml&serviceKey=Jjbx0uD%2FHOgqArO5zB6skbkmn%2F%2Bk1cb2fWr3tXbBF6u6tal1bZ8ZN7hPT3%2FzyWAiAK%2BoSXxY%2BtgetNr9bBCiIg%3D%3D')
print(r.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <response>
#   <header>
#     <resultCode>00</resultCode>
#     <resultMsg>NORMAL_CODE</resultMsg>
#   </header>
#   <body>
#     <items>
#       <item>
#         <clearVal>0.103</clearVal>
#         <sn>295</sn>
#         <maxVal>0.137</maxVal>
#         <districtName>충남</districtName>
#         <dataDate>2020-09-28</dataDate>
#         <issueVal>0.137</issueVal>
#         <issueLvl>1</issueLvl>
#         <issueTime>18</issueTime>
#         <moveName>서산시</moveName>
#         <clearTime>19</clearTime>
#       </item>
#       <item>
#         <clearVal>0.087</clearVal>
#         <sn>296</sn>
#         <maxVal>0.126</maxVal>
#         <districtName>충남</districtName>
#         <dataDate>2020-09-28</dataDate>
#         <issueVal>0.126</issueVal>
#         <issueLvl>1</issueLvl>
#         <issueTime>19</issueTime>
#         <moveName>당진시</moveName>
#         <clearTime>20</clearTime>
#       </item>
#       <item>
# ...

# %%
soup=BeautifulSoup(r.text,features="xml")

# %%
s1=soup.select('item>districtName')
s2=soup.select('item>issueVal')

# %%
for i in range(len(s1)):
  s1[i].append(s2[i])

# %%
s1
# Out:
# [<districtName>충남<issueVal>0.137</issueVal></districtName>,
#  <districtName>충남<issueVal>0.126</issueVal></districtName>,
#  <districtName>경북<issueVal>0.153</issueVal></districtName>,
#  <districtName>전남<issueVal>0.122</issueVal></districtName>,
#  <districtName>전남<issueVal>0.122</issueVal></districtName>,
#  <districtName>제주<issueVal>0.125</issueVal></districtName>,
#  <districtName>경북<issueVal>0.12</issueVal></districtName>,
#  <districtName>전남<issueVal>0.133</issueVal></districtName>,
#  <districtName>충남<issueVal>0.120</issueVal></districtName>,
#  <districtName>경남<issueVal>0.138</issueVal></districtName>,
#  <districtName>경남<issueVal>0.131</issueVal></districtName>,
#  <districtName>전남<issueVal>0.150</issueVal></districtName>,
#  <districtName>전남<issueVal>0.120</issueVal></districtName>,
#  <districtName>전남<issueVal>0.131</issueVal></districtName>,
#  <districtName>경남<issueVal>0.123</issueVal></districtName>,
#  <districtName>경남<issueVal>0.129</issueVal></districtName>,
# ...

# %%
print('학번=',2170014,'이름=','김수한')
# Out:
# 학번= 2170014 이름= 김수한
