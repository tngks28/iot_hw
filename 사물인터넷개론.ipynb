# %% [markdown]
# <a href="https://colab.research.google.com/github/tngks28/iot_hw/blob/main/%EC%82%AC%EB%AC%BC%EC%9D%B8%ED%84%B0%EB%84%B7%EA%B0%9C%EB%A1%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
r=requests.get('https://www.kobis.or.kr/kobis/mobile/main/findRealTicketList.do')
print(r.text)
# Out:
# <!doctype html>
# <html>
# <head>
# 	<meta charset="utf-8">
# 	<meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=no">
# 	<title>KOBIS 영화관 입장권 통합 전산망</title>
# 	<link rel="stylesheet" type="text/css" href="/kobis/web/comm/mobile/commcss/comm.css" />
# 	<link rel="stylesheet" type="text/css" href="/kobis/web/comm/mobile/commcss/cont.css" />
# 	<link rel="stylesheet" type="text/css" href="/kobis/web/comm/mobile/commcss/main.css" />
# 	<script type="text/javascript" src="/kobis/web/comm/mobile/commjs/jquery-1.12.4.min.js"></script>
# 	<script type="text/javascript" src="/kobis/web/comm/mobile/commjs/swipe.js"></script>
# 	<script type="text/javascript" src="/kobis/web/comm/mobile/commjs/kobis.js"></script>
# 	<script type="text/javascript" src="/kobis/web/comm/mobile/commjs/anypicker.js"></script>
# 	<script type="text/javascript" src="/kobis/web/comm/commjs/jquery.cookie.js"></script>
# 	<script>
# 		$(document).ready(function(){
# ...

# %%
# !pip install beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

# %%
html = BeautifulSoup(r.content, "html.parser")
li=html.find_all("li")
for l in li:
  a=l.find("strong")
  if a != None:
   print(a)
# Out:
# <strong class="tit ellip">파묘
# 								<span class="en ellip">
# 									(Exhuma)
# 								</span>
# </strong>
# <strong class="tit ellip">듄: 파트2
# 								<span class="en ellip">
# 									(Dune: Part Two)
# 								</span>
# </strong>
# <strong class="tit ellip">극장판 스파이 패밀리 코드 : 화이트
# 								<span class="en ellip">
# 									(SPY x FAMILY CODE: White)
# 								</span>
# </strong>
# <strong class="tit ellip">밥 말리: 원 러브
# 								<span class="en ellip">
# 									(Bob Marley: One Love)
# 								</span>
# </strong>
# <strong class="tit ellip">랜드 오브 배드
# 								<span class="en ellip">
# 									(Land of Bad)
# 								</span>
# </strong>
